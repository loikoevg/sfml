# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Неполное среднее', 'Среднее специальное', 'Ученая степень', 'Среднее', 'Неоконченное высшее', 'Два и более высших образования'}
#
#
# ==========
# MARITAL_STATUS
# {'Разведен(а)', 'Вдовец/Вдова', 'Не состоял в браке', 'Состою в браке', 'Гражданский брак'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Ресторанный бизнес/Общественное питание', 'Салоны красоты и здоровья', 'Сельское хозяйство', 'Логистика', 'Сборочные производства', 'Недвижимость', 'Химия/Парфюмерия/Фармацевтика', 'Энергетика', 'Нефтегазовая промышленность', 'Коммунальное хоз-во/Дорожные службы', 'Торговля', 'Государственная служба', 'Маркетинг', 'Страхование', 'Банк/Финансы', 'Подбор персонала', 'Другие сферы', 'Металлургия/Промышленность/Машиностроение', 'СМИ/Реклама/PR-агенства', 'Транспорт', 'Здравоохранение', 'Информационные технологии', 'Информационные услуги', 'Управляющая компания', 'Строительство', 'Юридические услуги/нотариальные услуги', 'ЧОП/Детективная д-ть', 'Развлечения/Искусство', 'Наука', 'Образование', 'Туризм'}
#
#
# ==========
# GEN_TITLE
# {'Высококвалифиц. специалист', nan, 'Руководитель среднего звена', 'Работник сферы услуг', 'Руководитель низшего звена', 'Руководитель высшего звена', 'Индивидуальный предприниматель', 'Рабочий', 'Партнер', 'Специалист', 'Служащий', 'Военнослужащий по контракту', 'Другое'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Частная ком. с инос. капиталом', 'Частная компания', 'Некоммерческая организация', 'Государственная комп./учреж.', 'Индивидуальный предприниматель'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
#
# ==========
# JOB_DIR
# {nan, 'Кадровая служба и секретариат', 'Реклама и маркетинг', 'Адм-хоз. и трансп. службы', 'Вспомогательный техперсонал', 'Бухгалтерия, финансы, планир.', 'Пр-техн. обесп. и телеком.', 'Служба безопасности', 'Снабжение и сбыт', 'Участие в основ. деятельности', 'Юридическая служба'}
#
#
# ==========
# FAMILY_INCOME
# {'свыше 50000 руб.', 'от 20000 до 50000 руб.', 'до 5000 руб.', 'от 5000 до 10000 руб.', 'от 10000 до 20000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
ский Бурятский АО', 'Бурятия', 'Ульяновская область', 'Костромская область', 'Еврейская АО', 'Ханты-Мансийский АО', 'Тульская область', 'Саратовская область', 'Агинский Бурятский АО', 'Москва', 'Липецкая область', 'Пензенская область', 'Астраханская область', 'Вологодская область', 'Удмуртия', 'Сахалинская область', 'Челябинская область', 'Магаданская область', 'Орловская область', 'Самарская область', 'Краснодарский край', 'Курганская область', 'Амурская область', 'Новгородская область', 'Горный Алтай'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Архангельская область', 'Чувашия', 'Калининградская область', 'Владимирская область', 'Ямало-Ненецкий АО', 'Карелия', 'Тверская область', 'Кировская область', 'Смоленская область', 'Омская область', 'Читинская область', 'Рязанская область', 'Калужская область', 'Башкирия', 'Хакасия', 'Ивановская область', 'Волгоградская область', 'Пермская область', 'Ставропольский край', 'Алтайский край', 'Дагестан', 'Красноярский край', 'Воронежская область', 'Санкт-Петербург', 'Томская область', 'Ростовская область', 'Ярославская область', 'Оренбургская область', 'Мурманская область', 'Эвенкийский АО', 'Кабардино-Балкария', 'Хабаровский край', 'Кемеровская область', 'Нижегородская область', 'Адыгея', 'Калмыкия', 'Мордовская республика', 'Псковская область', 'Ленинградская область', 'Московская область', 'Тюменская область', 'Тамбовская область', 'Приморский край', 'Якутия', 'Коми', 'Курская область', 'Брянская область', 'Марийская республика', 'Свердловская область', 'Карачаево-Черкесия', 'Белгородская область', 'Татарстан', 'Иркутская область', 'Камчатская область', 'Новосибирская область', 'Северная Осетия', 'Усть-Ордынский Бурятский АО', 'Бурятия', 'Ульяновская область', 'Костромская область', 'Еврейская АО', 'Ханты-Мансийский АО', 'Тульская область', 'Саратовская область', 'Агинский Бурятский АО', 'Москва', 'Липецкая область', 'Пензенская область', 'Астраханская область', 'Вологодская область', 'Удмуртия', 'Сахалинская область', 'Челябинская область', 'Магаданская область', 'Орловская область', 'Самарская область', 'Краснодарский край', 'Курганская область', 'Амурская область', 'Новгородская область', 'Горный Алтай'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Архангельская область', 'Чувашия', 'Калининградская область', 'Владимирская область', 'Ямало-Ненецкий АО', 'Карелия', 'Тверская область', 'Кировская область', 'Смоленская область', 'Омская область', 'Читинская область', 'Рязанская область', 'Калужская область', 'Башкирия', 'Хакасия', 'Ивановская область', 'Волгоградская область', 'Пермская область', 'Ставропольский край', 'Алтайский край', 'Красноярский край', 'Воронежская область', 'Санкт-Петербург', 'Томская область', 'Ростовская область', 'Ярославская область', 'Оренбургская область', 'Мурманская область', 'Эвенкийский АО', 'Кабардино-Балкария', 'Хабаровский край', 'Кемеровская область', 'Нижегородская область', 'Адыгея', 'Калмыкия', 'Мордовская республика', 'Псковская область', 'Ленинградская область', 'Московская область', 'Тюменская область', 'Тамбовская область', 'Приморский край', 'Якутия', 'Коми', 'Курская область', 'Брянская область', 'Марийская республика', 'Свердловская область', 'Карачаево-Черкесия', 'Белгородская область', 'Татарстан', 'Иркутская область', 'Камчатская область', 'Новосибирская область', 'Усть-Ордынский Бурятский АО', 'Северная Осетия', 'Бурятия', 'Ульяновская область', 'Костромская область', 'Еврейская АО', 'Ханты-Мансийский АО', 'Тульская область', 'Саратовская область', 'Агинский Бурятский АО', 'Москва', 'Липецкая область', 'Пензенская область', 'Астраханская область', 'Вологодская область', 'Удмуртия', 'Сахалинская область', 'Челябинская область', 'Магаданская область', 'Орловская область', 'Самарская область', 'Краснодарский край', 'Курганская область', 'Амурская область', 'Новгородская область', 'Горный Алтай'}
#
#
# ==========
# TP_PROVINCE
# {'Архангельская область', nan, 'Чувашия', 'Калининградская область', 'Владимирская область', 'Карелия', 'Тверская область', 'Кировская область', 'Смоленская область', 'Омская область', 'Читинская область', 'Рязанская область', 'Калужская область', 'Башкирия', 'Ивановская область', 'Волгоградская область', 'Ставропольский край', 'Пермская область', 'Алтайский край', 'Красноярский край', 'Воронежская область', 'Санкт-Петербург', 'Томская область', 'Ростовская область', 'Ярославская область', 'Оренбургская область', 'Мурманская область', 'Хабаровский край', 'Кемеровская область', 'Кабардино-Балкария', 'Нижегородская область', 'Адыгея', 'Мордовская республика', 'Псковская область', 'Тюменская область', 'Тамбовская область', 'Приморский край', 'Якутия', 'Коми', 'Курская область', 'Брянская область', 'Марийская республика', 'Свердловская область', 'Белгородская область', 'Татарстан', 'Иркутская область', 'Камчатская область', 'Новосибирская область', 'Бурятия', 'Ульяновская область', 'Костромская область', 'Еврейская АО', 'Ханты-Мансийский АО', 'Тульская область', 'Саратовская область', 'Москва', 'Липецкая область', 'Пензенская область', 'Астраханская область', 'Вологодская область', 'Удмуртия', 'Сахалинская область', 'Челябинская область', 'Магаданская область', 'Орловская область', 'Самарская область', 'Краснодарский край', 'Курганская область', 'Амурская область', 'Новгородская область', 'Горный Алтай'}
#
#
# ==========
# REGION_NM
# {'ЦЕНТРАЛЬНЫЙ 2', nan, 'УРАЛЬСКИЙ', 'СЕВЕРО-ЗАПАДНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ЗАПАДНО-СИБИРСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЮЖНЫЙ', 'ПРИВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'ПОВОЛЖСКИЙ'}
#
#
# ==========
# CREDIT
# {'65400', '9268', '20250', '14196', '16284', '16070,5', '12059,1', '24949,09', '9837', '13040', '26555', '14092', '8797', '29750', '2599,2', '17320', '19966', '18547', '25662', '3316', '21349', '6496,1', '4390,91', '23690,91', '17500', '16020', '40110', '11677', '23391', '9042', '35550', '17399,2', '16698', '4217', '22950', '31498', '9991', '13993', '24263', '22674', '31491', '10025', '45665', '20440', '16265', '11489,91', '27200', '8515', '35767,4', '11225', '17198', '21726', '14190', '10390', '31415', '15030', '6959', '23240', '26708', '23029', '19360', '35326', '95441', '29384', '4900', '48000', '7965', '23840', '32499', '8543', '14500', '15430', '14245', '45438', '19797', '5530', '14169,1', '50678', '10349', '42689', '17765', '13302', '2974,15', '4652', '19189', '83407', '
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()

    ## Your Code Here
    
    df_output.drop(columns=['AGREEMENT_RK'], inplace=True)
    df_output['PREVIOUS_CARD_NUM_UTILIZED'] = df_output.PREVIOUS_CARD_NUM_UTILIZED.fillna('0').astype('int')
    df_output['WORK_TIME'].fillna(df.WORK_TIME.mean(), inplace=True)
    df_output['PERSONAL_INCOME'] = df_output['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['CREDIT'] = df_output['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['FST_PAYMENT'] = df_output['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_AVG_DLQ_AMT'] = df_output['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_MAX_DLQ_AMT'] = df_output['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output = pd.get_dummies(df_output)
    
    
    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample_train == 1').drop(['sample_test', 'sample_train'], axis=1)
df_test_preproc = df_preproc.query('sample_test == 1').drop(['sample_test', 'sample_train'], axis=1)

# %%
df_test_preproc.shape
# Out:
# (14910, 443)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
y = df_train_preproc.TARGET
X = df_train_preproc.drop('TARGET', 1)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

## Your Code Here

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
predictDTC = dtc.predict(X_test)
predict_probaDTC = dtc.predict_proba(X_test)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
predictRFC = rfc.predict(X_test)
predict_probaRFC = rfc.predict_proba(X_test)

lr = LogisticRegression()
lr.fit(X_train, y_train)
predictLR = lr.predict(X_test)
predict_probaLR = lr.predict_proba(X_test)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here
    
print('DecisionTreeClassifier')
print('accuracy', accuracy_score(y_test, predictDTC))
print('precision', precision_score(y_test, predictDTC))
print('recall', recall_score(y_test, predictDTC))
print('RandomForestClassifier')
print('accuracy', accuracy_score(y_test, predictRFC))
print('precision', precision_score(y_test, predictRFC))
print('recall', recall_score(y_test, predictRFC))
print('LogisticRegression')
print('accuracy', accuracy_score(y_test, predictLR))
print('precision', precision_score(y_test, predictLR))
print('recall', recall_score(y_test, predictLR))

DTCseries = pd.Series([accuracy_score(y_test, predictDTC), 
                       precision_score(y_test, predictDTC), 
                       recall_score(y_test, predictDTC)], 
                      index = ['accuracy', 'precision', 'recall'])

RFCseries = pd.Series([accuracy_score(y_test, predictRFC), 
                       precision_score(y_test, predictRFC), 
                       recall_score(y_test, predictRFC)], 
                      index = ['accuracy', 'precision', 'recall'])

LRseries = pd.Series([accuracy_score(y_test, predictLR), 
                       precision_score(y_test, predictLR), 
                       recall_score(y_test, predictLR)], 
                      index = ['accuracy', 'precision', 'recall'])
# Out:
# DecisionTreeClassifier
# accuracy 0.791548062185242
# precision 0.15236427320490367
# recall 0.15675675675675677
# RandomForestClassifier
# accuracy 0.8751915918546092
# precision 0.058823529411764705
# recall 0.0018018018018018018
# LogisticRegression
# accuracy 0.877819137289249
# precision 0.2857142857142857
# recall 0.0036036036036036037

# %%
statDF = pd.DataFrame({'DecisionTreeClassifier':DTCseries,
                     'RandomForestClassifier':RFCseries,
                     'LogisticRegression':LRseries})

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
