# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    30133 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Неполное среднее', 'Ученая степень', 'Среднее', 'Высшее', 'Два и более высших образования', 'Среднее специальное', 'Неоконченное высшее'}
#
#
# ==========
# MARITAL_STATUS
# {'Гражданский брак', 'Вдовец/Вдова', 'Состою в браке', 'Разведен(а)', 'Не состоял в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Салоны красоты и здоровья', 'Информационные услуги', 'Логистика', 'Страхование', 'Здравоохранение', 'Государственная служба', 'Информационные технологии', 'Туризм', 'Ресторанный бизнес/Общественное питание', 'Недвижимость', 'Строительство', 'Юридические услуги/нотариальные услуги', 'Управляющая компания', 'Коммунальное хоз-во/Дорожные службы', 'Химия/Парфюмерия/Фармацевтика', 'Маркетинг', 'Энергетика', 'Развлечения/Искусство', 'Торговля', 'Банк/Финансы', 'Другие сферы', 'Подбор персонала', 'Транспорт', 'СМИ/Реклама/PR-агенства', 'Сборочные производства', 'ЧОП/Детективная д-ть', 'Металлургия/Промышленность/Машиностроение', 'Сельское хозяйство', 'Нефтегазовая промышленность', 'Образование', 'Наука'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Служащий', 'Другое', 'Руководитель высшего звена', 'Руководитель среднего звена', 'Высококвалифиц. специалист', 'Индивидуальный предприниматель', 'Работник сферы услуг', 'Партнер', 'Специалист', 'Военнослужащий по контракту', 'Руководитель низшего звена', 'Рабочий'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Некоммерческая организация', 'Частная компания', 'Индивидуальный предприниматель', 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {nan, 'Снабжение и сбыт', 'Пр-техн. обесп. и телеком.', 'Участие в основ. деятельности', 'Кадровая служба и секретариат', 'Юридическая служба', 'Служба безопасности', 'Адм-хоз. и трансп. службы', 'Реклама и маркетинг', 'Бухгалтерия, финансы, планир.', 'Вспомогательный техперсонал'}
#
#
# ==========
# FAMILY_INCOME
# {'от 20000 до 50000 руб.', 'от 10000 до 20000 руб.', 'свыше 50000 руб.', 'от 5000 до 10000 руб.', 'до 5000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'7600', '13700', '8200', '17700', '13000', '5700', '60000', '21800', '4800', '13600', '15500', '2000', '12300', '13160', '22000', '17200', '4590', '12000', '4000', '16100', '3200', '15600', '9900', '11800', '5425', '21000', '13150', '17900', '17404', '16800', '4300', '25000', '7800', '22500', '19300', '170000', '27300', '5200', '80000', '26500', '10500', '16700', '10100', '16000', '5100', '15000', '12650', '42500', '16500', '43000', '9240', '11400', '13900', '23100', '12600', '49000', '5088', '9000', '18700', '23000', '5000', '35000', '47000', '9200', '3400', '48000', '10700', '5790', '7200', '10400', '7550', '92000', '5582', '5500', '42000', '8000', '12100', '4330', '250000', '19700', '45000', '7650', '13800', '13400', '20646,16', '5460', '7220', '23500', '18000', '4400', '12400', '13300', '6300', '11900', '40000', '4515', '4600', '29500', '4700', '5360', '67700', '5050', '7000', '14000', '10600', '100000', '8400', '30000', '17800', '16200', '4500', '21500', '14358', '17000', '9330', '5400', '8900', '9400', '7250', '46000', '24800', '11640', '65000', '12900', '3100', '50000', '7850', '6000', '7640', '5339', '12500', '10200', '16900', '15300', '6299,19', '4950', '3600', '51000', '12700', '8350', '7300', '55000', '24', '14800', '7101', '5350', '19000', '54000', '31000', '10300', '44000', '5300', '5900', '6700', '11700', '9628', '1950', '16050', '24500', '4900', '6800', '70000', '15400', '9500', '26000', '7700', '3800', '77000', '8100', '6100', '6900', '9340', '22955', '20500', '67000', '7400', '3500', '27000', '32640', '5680', '28000', '5800', '6670', '37000', '33000', '8700', '8800', '160000', '8250', '18500', '13200', '9100', '34000', '4100', '3300', '3000', '4200', '29800', '56000', '2800', '3700', '9300', '8500', '53000', '29000', '6359', '4360', '8300', '8600', '6200', '14700', '32000', '12800', '11300', '41900', '150000', '15380', '23800', '7100', '11500', '25800', '3900', '6400', '5600', '7050', '75000', '11200', '14500', '6600', '7251', '24000', '110000', '36000', '2300', '8726', '8066', '10800', '17600', '38000', '2100', '220000', '4340', '13450', '6608', '41000', '9800', '39000', '18200', '11000', '52000', '9600', '7500', '18600', '15200', '68000', '11600', '19500', '7900', '5446', '14300', '19800', '7830', '19600', '28300', '10000', '6500', '17500', '6180', '13500', '9700', '10900', '5230', '20000', '15560'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Тульская область', 'Краснодарский край', 'Татарстан', 'Кабардино-Балкария', 'Воронежская область', 'Хакасия', 'Карачаево-Черкесия', 'Курская область', 'Ленинградская область', 'Ханты-Мансийский АО', 'Томская область', 'Ульяновская область', 'Тюменская область', 'Эвенкийский АО', 'Волгоградская область', 'Башкирия', 'Хабаровский край', 'Вологодская область', 'Приморский край', 'Нижегородская область', 'Удмуртия', 'Камчатская область', 'Оренбургская область', 'Липецкая область', 'Тверская область', 'Саратовская область', 'Санкт-Петербург', 'Псковская область', 'Мурманская область', 'Астраханская область', 'Пермская область', 'Алтайский край', 'Мордовская республика', 'Усть-Ордынский Бурятский АО', 'Калининградская область', 'Белгородская область', 'Пензенская область', 'Калмыкия', 'Иркутская область', 'Тамбовская область', 'Калужская область', 'Москва', 'Якутия', 'Орловская область', 'Чувашия', 'Горный Алтай', 'Смоленская область', 'Рязанская область', 'Карелия', 'Московская область', 'Северная Осетия', 'Костромская область', 'Коми', 'Челябинская область', 'Курганская область', 'Новосибирская область', 'Амурская область', 'Ростовская область', 'Кировская область', 'Самарская область', 'Кемеровская область', 'Сахалинская область', 'Марийская республика', 'Ярославская область', 'Агинский Бурятский АО', 'Дагестан', 'Новгородская область', 'Омская область', 'Адыгея', 'Ивановская область', 'Магаданская область', 'Красноярский край', 'Владимирская область', 'Бурятия', 'Брянская область', 'Ставропольский край', 'Свердловская область', 'Ямало-Ненецкий АО', 'Читинская область', 'Архангельская область', 'Еврейская АО'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Тульская область', 'Краснодарский край', 'Татарстан', 'Кабардино-Балкария', 'Воронежская область', 'Хакасия', 'Карачаево-Черкесия', 'Курская область', 'Ленинградская область', 'Ханты-Мансийский АО', 'Томская область', 'Ульяновская область', 'Тюменская область', 'Эвенкийский АО', 'Волгоградская область', 'Башкирия', 'Хабаровский край', 'Вологодская область', 'Приморский край', 'Нижегородская область', 'Удмуртия', 'Камчатская область', 'Оренбургская область', 'Липецкая область', 'Тверская область', 'Саратовская область', 'Санкт-Петербург', 'Псковская область', 'Мурманская область', 'Астраханская область', 'Пермская область', 'Алтайский край', 'Мордовская республика', 'Усть-Ордынский Бурятский АО', 'Калининградская область', 'Белгородская область', 'Пензенская область', 'Калмыкия', 'Иркутская область', 'Тамбовская область', 'Калужская область', 'Москва', 'Якутия', 'Орловская область', 'Чувашия', 'Горный Алтай', 'Смоленская область', 'Рязанская область', 'Карелия', 'Московская область', 'Северная Осетия', 'Костромская область', 'Коми', 'Челябинская область', 'Курганская область', 'Новосибирская область', 'Амурская область', 'Ростовская область', 'Кировская область', 'Самарская область', 'Кемеровская область', 'Сахалинская область', 'Марийская республика', 'Ярославская область', 'Агинский Бурятский АО', 'Дагестан', 'Новгородская область', 'Омская область', 'Адыгея', 'Ивановская область', 'Магаданская область', 'Красноярский край', 'Владимирская область', 'Бурятия', 'Брянская область', 'Ставропольский край', 'Свердловская область', 'Ямало-Ненецкий АО', 'Читинская область', 'Архангельская область', 'Еврейская АО'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Тульская область', 'Краснодарский край', 'Татарстан', 'Кабардино-Балкария', 'Воронежская область', 'Хакасия', 'Карачаево-Черкесия', 'Курская область', 'Ленинградская область', 'Ханты-Мансийский АО', 'Томская область', 'Ульяновская область', 'Тюменская область', 'Эвенкийский АО', 'Волгоградская область', 'Башкирия', 'Хабаровский край', 'Вологодская область', 'Приморский край', 'Нижегородская область', 'Удмуртия', 'Камчатская область', 'Оренбургская область', 'Липецкая область', 'Тверская область', 'Саратовская область', 'Санкт-Петербург', 'Псковская область', 'Мурманская область', 'Астраханская область', 'Пермская область', 'Алтайский край', 'Мордовская республика', 'Усть-Ордынский Бурятский АО', 'Калининградская область', 'Белгородская область', 'Пензенская область', 'Калмыкия', 'Иркутская область', 'Тамбовская область', 'Калужская область', 'Москва', 'Якутия', 'Орловская область', 'Чувашия', 'Горный Алтай', 'Смоленская область', 'Рязанская область', 'Карелия', 'Московская область', 'Северная Осетия', 'Костромская область', 'Коми', 'Челябинская область', 'Курганская область', 'Новосибирская область', 'Амурская область', 'Ростовская область', 'Кировская область', 'Самарская область', 'Кемеровская область', 'Сахалинская область', 'Марийская республика', 'Ярославская область', 'Агинский Бурятский АО', 'Новгородская область', 'Омская область', 'Адыгея', 'Ивановская область', 'Магаданская область', 'Красноярский край', 'Владимирская область', 'Бурятия', 'Брянская область', 'Ставропольский край', 'Свердловская область', 'Ямало-Ненецкий АО', 'Читинская область', 'Архангельская область', 'Еврейская АО'}
#
#
# ==========
# TP_PROVINCE
# {'Тульская область', nan, 'Краснодарский край', 'Татарстан', 'Воронежская область', 'Кабардино-Балкария', 'Курская область', 'Ханты-Мансийский АО', 'Томская область', 'Ульяновская область', 'Тюменская область', 'Волгоградская область', 'Башкирия', 'Хабаровский край', 'Вологодская область', 'Приморский край', 'Нижегородская область', 'Удмуртия', 'Камчатская область', 'Оренбургская область', 'Липецкая область', 'Санкт-Петербург', 'Тверская область', 'Саратовская область', 'Псковская область', 'Мурманская область', 'Астраханская область', 'Пермская область', 'Алтайский край', 'Мордовская республика', 'Калининградская область', 'Белгородская область', 'Пензенская область', 'Иркутская область', 'Тамбовская область', 'Калужская область', 'Москва', 'Якутия', 'Орловская область', 'Чувашия', 'Горный Алтай', 'Смоленская область', 'Рязанская область', 'Карелия', 'Костромская область', 'Коми', 'Челябинская область', 'Курганская область', 'Новосибирская область', 'Амурская область', 'Ростовская область', 'Кировская область', 'Самарская область', 'Кемеровская область', 'Сахалинская область', 'Марийская республика', 'Ярославская область', 'Новгородская область', 'Омская область', 'Адыгея', 'Ивановская область', 'Магаданская область', 'Красноярский край', 'Владимирская область', 'Бурятия', 'Брянская область', 'Ставропольский край', 'Свердловская область', 'Читинская область', 'Архангельская область', 'Еврейская АО'}
#
#
# ==========
# REGION_NM
# {'СЕВЕРО-ЗАПАДНЫЙ', nan, 'УРАЛЬСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ПРИВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ПОВОЛЖСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ЗАПАДНО-СИБИРСКИЙ', 'ЮЖНЫЙ', 'ЦЕНТРАЛЬНЫЙ 1'}
#
#
# ==========
# CREDIT
# {'3250', '3545', '3703', '13193', '26397', '23985', '16897', '9150', '8651', '22930', '43732,8', '10445', '10080', '11619,84', '12380', '3950', '23355', '19720', '45672', '11724', '22269', '5105,7', '9998', '9955', '9738', '17780', '14550', '3390', '7090', '17240', '43200', '5380', '16150', '27599', '23577', '34120', '18216', '35100', '14290', '15070', '14229', '22560', '21030', '21950', '7787', '34500', '21015', '3280', '7693', '22944', '9429', '4761', '21487', '4962', '20670', '5360', '16317', '5155', '7558', '5050', '16330', '16371', '14000', '19170', '14170', '17254', '11416', '3547', '10526', '13456,82', '35598', '12360', '22212', '10734', '4653', '7695', '17399,2', '16783', '23990,83', '23040', '18560', '34557,1', '5980', '9898', '7422', '17839,92', '24330', '10584', '39450', '2930', '25150', '23147', '16993', '11450,9', '10354', '5949', '11540', '14438', '24220', '9980', '3892', '11691', '8492', '7197', '5612', '26590', '9009', '6519', '3764', '6964', '13820', '18730', '13410', '4851,81', '4242',
,77', '2263,2', '1088,05', '2370', '3110', '1176,82', '1459,99', '1222,06', '177,34', '2858,62', '4320', '880,2', '1150', '510', '2044,32', '908,78', '2830', '1828,89', '5075,99', '3700', '4260', '63,31', '1288,7', '1080', '1477,37', '3660', '543,33', '2550', '1509,44', '704,93', '2497,09', '8020', '1742,41', '660', '1833,77', '7100', '1679,2', '1090,8', '760', '2700', '2030', '3010', '800', '863,68', '3470', '3770', '2360', '603,55', '2150', '2530', '100', '438,19', '224,59', '1770', '444', '5870', '1960', '554,36', '2610', '2642,83', '6070', '2160', '762,93', '875,2', '726,57', '2503,19', '699,78', '613,21', '1819,26', '2490', '6500', '970', '1359,6', '5140', '567,16', '2051,5', '7340', '4680', '2970', '830,7', '1440', '578,06', '2429,09', '790', '580', '2000', '1851,55', '1620', '3762,5', '572,22', '3626,91', '3716,35', '2064,08', '1539,2', '1420', '5048,19', '2140', '769,43', '1093,75', '2630', '1530', '1408,32', '6080', '862,5', '330', '1792,71', '990,85', '269,51', '3768,7', '1538,69', '1380', '3560', '880', '1433,4', '4001,34', '5650', '2590', '840', '1134,58', '596,29', '367', '2090', '930', '549,88', '2365,47', '896,31', '1761,03', '136,76', '1819,09', '4450', '3620', '1840,14', '2540', '3202,2', '3060', '5560', '1671,7', '1280', '2547,85', '1180', '1006,59', '1010,55', '2500', '1626,75', '4830', '1296,74', '1490', '1508,79', '1599,9', '2430', '980,42', '1387,47', '568,7', '948,58', '1550', '1179,86', '892,95', '684,89', '3760', '1953,6', '5160', '3201,95', '1052,63', '1130', '1909,16', '4400', '2120', '3940', '1985,3', '18310', '5394,29', '1931,44', '650', '840,4', '4700', '3433,42', '2477,64', '4600', '990', '1429,99', '1090,01', '2005,15', '1196,43', '49,35', '1340', '2779,4', '1020', '2790', '604,76', '791,98', '1140', '2119,77', '2518,18', '821,93', '2524,28', '4550', '370,77', '1030', '6660', '946,49', '2361,22', '1670', '599,19', '3089,5', '3480', '1220', '2620', '856,64', '3600', '3510', '849,91', '1630', '875,09', '1860,72', '1060', '1154,34', '5170', '5397,15', '481,51', '2349,51', '3959', '2350', '1312,44', '1610', '400', '2707,25', '755,76', '1230', '1259,39', '2262,12', '1740,19', '957,63', '2870', '1050', '2010', '446,31', '4240', '4660', '1113,74', '1138,2', '5850', '94,89', '4210', '429,11', '289,02', '1959,99', '1350', '700', '620', '892,18', '2390', '2202,69', '1841,9', '1066', '820', '937,79', '2910', '3910', '3540', '3500', '1190', '1405,53', '2647,9', '988,85', '3501,45', '2287,02', '1733,88', '62,46', '4960', '38,32', '862,43', '3000', '4200', '1110,39', '1837,31', '1729,66', '28012,2', '960', '1260', '1259,1', '859,9 ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
PREVIOUS_CARD_NUM_UTILIZED - все пропуски заменяем на ноль (по условию из описания отсутствие данных == 0)

# %%
df.PREVIOUS_CARD_NUM_UTILIZED = df.PREVIOUS_CARD_NUM_UTILIZED.fillna(0)

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26840 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  26840 non-null int64
# TARGET                        26840 non-null int64
# AGE                           26840 non-null int64
# SOCSTATUS_WORK_FL             26840 non-null int64
# SOCSTATUS_PENS_FL             26840 non-null int64
# GENDER                        26840 non-null int64
# CHILD_TOTAL                   26840 non-null int64
# DEPENDANTS                    26840 non-null int64
# EDUCATION                     26840 non-null object
# MARITAL_STATUS                26840 non-null object
# GEN_INDUSTRY                  26840 non-null object
# GEN_TITLE                     26840 non-null object
# ORG_TP_STATE                  26840 non-null object
# ORG_TP_FCAPITAL               26840 non-null object
# JOB_DIR                       26840 non-null object
# FAMILY_INCOME                 26840 non-null object
# PERSONAL_INCOME               26840 non-null object
# REG_ADDRESS_PROVINCE          26840 non-null object
# FACT_ADDRESS_PROVINCE         26840 non-null object
# POSTAL_ADDRESS_PROVINCE       26840 non-null object
# TP_PROVINCE                   26840 non-null object
# REGION_NM                     26840 non-null object
# REG_FACT_FL                   26840 non-null int64
# FACT_POST_FL                  26840 non-null int64
# REG_POST_FL                   26840 non-null int64
# REG_FACT_POST_FL              26840 non-null int64
# REG_FACT_POST_TP_FL           26840 non-null int64
# FL_PRESENCE_FL                26840 non-null int64
# OWN_AUTO                      26840 non-null int64
# AUTO_RUS_FL                   26840 non-null int64
# HS_PRESENCE_FL                26840 non-null int64
# COT_PRESENCE_FL               26840 non-null int64
# GAR_PRESENCE_FL               26840 non-null int64
# LAND_PRESENCE_FL              26840 non-null int64
# CREDIT                        26840 non-null object
# TERM                          26840 non-null int64
# FST_PAYMENT                   26840 non-null object
# DL_DOCUMENT_FL                26840 non-null int64
# GPF_DOCUMENT_FL               26840 non-null int64
# FACT_LIVING_TERM              26840 non-null int64
# WORK_TIME                     26840 non-null float64
# FACT_PHONE_FL                 26840 non-null int64
# REG_PHONE_FL                  26840 non-null int64
# GEN_PHONE_FL                  26840 non-null int64
# LOAN_NUM_TOTAL                26840 non-null int64
# LOAN_NUM_CLOSED               26840 non-null int64
# LOAN_NUM_PAYM                 26840 non-null int64
# LOAN_DLQ_NUM                  26840 non-null int64
# LOAN_MAX_DLQ                  26840 non-null int64
# LOAN_AVG_DLQ_AMT              26840 non-null object
# LOAN_MAX_DLQ_AMT              26840 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    26840 non-null float64
# sample                        26840 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 11.1+ MB

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    
    
    ## Your Code Here
    
    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

## Your Code Here

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
